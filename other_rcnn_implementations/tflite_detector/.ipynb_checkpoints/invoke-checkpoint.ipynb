# %% [markdown]
# This model was taken from https://www.tensorflow.org/lite/models/object_detection/overview

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches
from PIL import Image

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="coco_ssd_mobilenet_v1_1.0_quant_2018_06_29/detect.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.uint8)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[1]['index'])
output_data
# Out:
# array([[71.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]], dtype=float32)

# %%
output_details
# Out:
# [{'name': 'TFLite_Detection_PostProcess',
#   'index': 167,
#   'shape': array([ 1, 10,  4], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'TFLite_Detection_PostProcess:1',
#   'index': 168,
#   'shape': array([ 1, 10], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'TFLite_Detection_PostProcess:2',
#   'index': 169,
#   'shape': array([ 1, 10], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'TFLite_Detection_PostProcess:3',
#   'index': 170,
#   'shape': array([1], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)}]

# %%
input_details
# Out:
# [{'name': 'normalized_input_image_tensor',
#   'index': 175,
#   'shape': array([  1, 300, 300,   3], dtype=int32),
#   'dtype': numpy.uint8,
#   'quantization': (0.0078125, 128)}]

# %%
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.uint8)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(174)
print(output_data.shape)
# Out:
# (1, 1917, 91)

# %%
img = np.array(Image.open('nyc.jpg'))
with tf.Session() as sess:
    img = sess.run(tf.cast(tf.image.resize(img, (300,300)), tf.uint8))

# %%
interpreter.set_tensor(input_details[0]['index'], img[None,:,:,:])
interpreter.invoke()

# %%
patches = interpreter.get_tensor(167)[0]*300

fig,ax = plt.subplots(1)
ax.imshow(img)
for top, left, bottom, right in patches:
    dx = right - left
    dy = bottom - top
    ax.add_patch(matplotlib.patches.Rectangle((top,left)[::-1],dx,dy,linewidth=1,edgecolor='r',facecolor='none'))

# %%
interpreter.get_tensor(173) # feature vectors?
# Out:
# array([[[106, 158, 133, ..., 130, 123, 116],
#         [105, 110,  93, ..., 101,  88,  78],
#         [106, 106, 101, ...,  99,  96,  91],
#         ...,
#         [128, 171, 146, ..., 157, 130, 137],
#         [129, 137, 136, ..., 142, 130, 138],
#         [130, 130, 130, ..., 130, 130, 130]]], dtype=uint8)

# %%
interpreter.get_tensor(169)
# Out:
# array([[0.64453125, 0.64453125, 0.62109375, 0.59765625, 0.5859375 ,
#         0.5859375 , 0.57421875, 0.57421875, 0.5625    , 0.5625    ]],
#       dtype=float32)

# %%
